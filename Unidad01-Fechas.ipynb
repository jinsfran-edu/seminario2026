# %% [markdown]
# # Unidad 01
# ## Trabajando con Fecha y Hora

# %%
SELECT IDPedido, IDCliente, IDEmpleado, FechaEnvio
FROM Pedidos
WHERE FechaEnvio = '20210212';
# Out:
# (5 rows affected)
#
# IDPedido | IDCliente | IDEmpleado | FechaEnvio
# ---------+-----------+------------+------------------------
# 10865    | QUICK     | 2          | 2021-02-12 00:00:00.000
# 10866    | BERGS     | 5          | 2021-02-12 00:00:00.000
# 10876    | BONAP     | 7          | 2021-02-12 00:00:00.000
# 10878    | QUICK     | 4          | 2021-02-12 00:00:00.000
# 10879    | WILMK     | 3          | 2021-02-12 00:00:00.000
# (5 rows)
#
# Total execution time: 00:00:00.012

# %%
SELECT @@LANGUAGE
# Out:
# (1 row affected)
#
# (No column name)
# ----------------
# us_english
# (1 row)
#
# Total execution time: 00:00:00.115

# %%
SET LANGUAGE us_english; 
SELECT DATENAME(month,CAST('2007-12-02' AS DATETIME));
SELECT DATENAME(month,CAST('20071202' AS DATETIME));
# Out:
# Changed language setting to us_english.
# (1 row affected)
# (1 row affected)
#
# (No column name)
# ----------------
# December
# (1 row)
#
# (No column name)
# ----------------
# December
# (1 row)
#
# Total execution time: 00:00:01.645

# %%
SET LANGUAGE British; 
SELECT DATENAME(month,CAST('2007-12-02' AS DATETIME));
SELECT DATENAME(month,CAST('20071202' AS DATETIME));
# Out:
# Changed language setting to British.
# (1 row affected)
# (1 row affected)
#
# (No column name)
# ----------------
# February
# (1 row)
#
# (No column name)
# ----------------
# December
# (1 row)
#
# Total execution time: 00:00:37.476

# %%
SET LANGUAGE us_english;
# Out:
# Changed language setting to us_english.
# Total execution time: 00:00:00.002

# %%
SELECT @@LANGUAGE
SET LANGUAGE British; 
SELECT CAST('02/12/2007' AS DATETIME); 
SET LANGUAGE us_english; 
SELECT CAST('02/12/2007' AS DATETIME);
# Out:
# (1 row affected)
# Changed language setting to British.
# (1 row affected)
# Changed language setting to us_english.
# (1 row affected)
#
# (No column name)
# ----------------
# us_english
# (1 row)
#
# (No column name)
# -----------------------
# 2007-12-02 00:00:00.000
# (1 row)
#
# (No column name)
# -----------------------
# 2007-02-12 00:00:00.000
# (1 row)
#
# Total execution time: 00:00:37.420

# %%
SET DATEFORMAT dmy;  
GO  
DECLARE @datevar datetime2 = '31/12/2008 09:01:01.1234567';  
SELECT @datevar;  
GO  

SET DATEFORMAT dmy;  
GO  
DECLARE @datevar datetime2 = '12/31/2008 09:01:01.1234567';  
SELECT @datevar;  
GO
# Out:
# Commands completed successfully.
#
# (1 row affected)
#
# (No column name)
# ---------------------------
# 2008-12-31 09:01:01.1234567
# (1 row)
#
# Commands completed successfully.
#
# Msg 241, Level 16, State 1, Line 9
# Conversion failed when converting date and/or time from character string.
#
# Total execution time: 00:00:00.954

# %%
SET LANGUAGE British; 
SELECT CAST('20070212' AS DATETIME); 
SET LANGUAGE us_english; 
SELECT CAST('20070212' AS DATETIME);
# Out:
# Changed language setting to British.
# (1 row affected)
# Changed language setting to us_english.
# (1 row affected)
#
# (No column name)
# -----------------------
# 2007-02-12 00:00:00.000
# (1 row)
#
# (No column name)
# -----------------------
# 2007-02-12 00:00:00.000
# (1 row)
#
# Total execution time: 00:00:38.514

# %%
SELECT CONVERT(DATETIME, '02/12/2007', 101);
SELECT CONVERT(DATETIME, '02/12/2007', 103);
# Out:
# (1 row affected)
# (1 row affected)
#
# (No column name)
# -----------------------
# 2007-02-12 00:00:00.000
# (1 row)
#
# (No column name)
# -----------------------
# 2007-12-02 00:00:00.000
# (1 row)
#
# Total execution time: 00:00:00.014

# %%
SELECT CAST('12:30:15.123' AS DATETIME);
# Out:
# (1 row affected)
#
# (No column name)
# -----------------------
# 1900-01-01 12:30:15.123
# (1 row)
#
# Total execution time: 00:00:00.007

# %%
SELECT IDPedido, IDCliente, IDEmpleado, FechaPedido
FROM Pedidos
WHERE FechaPedido >= '20210212'
AND FechaPedido < '20210213';
# Out:
# (3 rows affected)
#
# IDPedido | IDCliente | IDEmpleado | FechaPedido
# ---------+-----------+------------+------------------------
# 10883    | LONEP     | 8          | 2021-02-12 17:48:00.000
# 10884    | LETSS     | 4          | 2021-02-12 18:38:00.000
# 10885    | SUPRD     | 6          | 2021-02-12 14:28:00.000
# (3 rows)
#
# Total execution time: 00:00:00.011

# %%
SELECT IDPedido, IDCliente, IDEmpleado, FechaPedido
FROM Pedidos
WHERE FechaPedido >= '20210101' AND FechaPedido < '20220101';
# Out:
# (270 rows affected)
#
# IDPedido | IDCliente | IDEmpleado | FechaPedido
# ---------+-----------+------------+------------------------
# 10808    | OLDWO     | 2          | 2021-01-01 17:39:00.000
# 10809    | WELLI     | 7          | 2021-01-01 17:40:00.000
# 10810    | LAUGB     | 2          | 2021-01-01 14:54:00.000
# 10811    | LINOD     | 8          | 2021-01-02 17:49:00.000
# 10812    | REGGC     | 5          | 2021-01-02 16:49:00.000
# 10813    | RICAR     | 1          | 2021-01-05 17:35:00.000
# 10814    | VICTE     | 3          | 2021-01-05 17:53:00.000
# 10815    | SAVEA     | 2          | 2021-01-05 15:11:00.000
# 10816    | GREAL     | 4          | 2021-01-06 18:52:00.000
# 10817    | KOENE     | 3          | 2021-01-06 12:47:00.000
# 10818    | MAGAA     | 7          | 2021-01-07 13:18:00.000
# 10819    | CACTU     | 2          | 2021-01-07 17:43:00.000
# 10820    | RATTC     | 3          | 2021-01-07 14:52:00.000
# 10821    | SPLIR     | 1          | 2021-01-08 14:43:00.000
# 10822    | TRAIH     | 6          | 2021-01-08 17:32:00.000
# 10823    | LILAS     | 5          | 2021-01-09 15:41:00.000
# 10824    | FOLKO     | 8          | 2021-01-09 18:22:00.000
# 10825    | DRACD     | 1          | 2021-01-09 12:37:00.000
# 10826    | BLONP     | 6          | 2021-01-12 13:55:00.000
# 10827    | BONAP     | 1          | 2021-01-12 15:43:00.000
# 10828    | RANCH     | 9          | 2021-01-13 13:15:00.000
# 10829    | ISLAT     | 9          | 2021-01-13 12:43:00.000
# 10830    | TRADH     | 4          | 2021-01-13 12:10:00.000
# 10831    | SANTG     | 3          | 2021-01-14 13:21:00.000
# 11069    | TORTU     | 1          | 2021-05-04 18:28:00.000
# 11070    | LEHMS     | 2          | 2021-05-05 16:25:00.000
# 11071    | LILAS     | 1          | 2021-05-05 17:49:00.000
# 11072    | ERNSH     | 4          | 2021-05-05 18:32:00.000
# 11073    | PERIC     | 2          | 2021-05-05 17:30:00.000
# 11074    | SIMOB     | 7          | 2021-05-06 18:32:00.000
# 11075    | RICSU     | 8          | 2021-05-06 13:39:00.000
# 11076    | BONAP     | 4          | 2021-05-06 17:40:00.000
# 11077    | RATTC     | 1          | 2021-05-06 18:40:00.000
# (270 rows)
#
# Total execution time: 00:00:00.016

# %%
SELECT IDPedido, IDCliente, IDEmpleado, FechaPedido
FROM Pedidos
WHERE YEAR(FechaPedido) = 2021;
# Out:
# (270 rows affected)
#
# IDPedido | IDCliente | IDEmpleado | FechaPedido
# ---------+-----------+------------+------------------------
# 10808    | OLDWO     | 2          | 2021-01-01 17:39:00.000
# 10809    | WELLI     | 7          | 2021-01-01 17:40:00.000
# 10810    | LAUGB     | 2          | 2021-01-01 14:54:00.000
# 10811    | LINOD     | 8          | 2021-01-02 17:49:00.000
# 10812    | REGGC     | 5          | 2021-01-02 16:49:00.000
# 10813    | RICAR     | 1          | 2021-01-05 17:35:00.000
# 10814    | VICTE     | 3          | 2021-01-05 17:53:00.000
# 10815    | SAVEA     | 2          | 2021-01-05 15:11:00.000
# 10816    | GREAL     | 4          | 2021-01-06 18:52:00.000
# 10817    | KOENE     | 3          | 2021-01-06 12:47:00.000
# 10818    | MAGAA     | 7          | 2021-01-07 13:18:00.000
# 10819    | CACTU     | 2          | 2021-01-07 17:43:00.000
# 10820    | RATTC     | 3          | 2021-01-07 14:52:00.000
# 10821    | SPLIR     | 1          | 2021-01-08 14:43:00.000
# 10822    | TRAIH     | 6          | 2021-01-08 17:32:00.000
# 10823    | LILAS     | 5          | 2021-01-09 15:41:00.000
# 10824    | FOLKO     | 8          | 2021-01-09 18:22:00.000
# 10825    | DRACD     | 1          | 2021-01-09 12:37:00.000
# 10826    | BLONP     | 6          | 2021-01-12 13:55:00.000
# 10827    | BONAP     | 1          | 2021-01-12 15:43:00.000
# 10828    | RANCH     | 9          | 2021-01-13 13:15:00.000
# 10829    | ISLAT     | 9          | 2021-01-13 12:43:00.000
# 10830    | TRADH     | 4          | 2021-01-13 12:10:00.000
# 10831    | SANTG     | 3          | 2021-01-14 13:21:00.000
# 10832    | LAMAI     | 2          | 2021-01-14 12:13:00.000
# 10833    | OTTIK     | 6          | 2021-01-15 12:27:00.000
# 10834    | TRADH     | 1          | 2021-01-15 13:54:00.000
# 10835    | ALFKI     | 1          | 2021-01-15 13:18:00.000
# 10836    | ERNSH     | 7          | 2021-01-16 16:39:00.000
# 10837    | BERGS     | 9          | 2021-01-16 16:21:00.000
# 10838    | LINOD     | 3          | 2021-01-19 12:35:00.000
# 10839    | TRADH     | 3          | 2021-01-19 18:35:00.000
# 10840    | LINOD     | 4          | 2021-01-19 13:27:00.000
# 10841    | SUPRD     | 5          | 2021-01-20 12:59:00.000
# 10896    | MAISD     | 7          | 2021-02-19 15:18:00.000
# 10897    | HUNGO     | 3          | 2021-02-19 13:36:00.000
# 10898    | OCEAN     | 4          | 2021-02-20 16:40:00.000
# 10899    | LILAS     | 5          | 2021-02-20 17:52:00.000
# 10900    | WELLI     | 1          | 2021-02-20 12:43:00.000
# 10901    | HILAA     | 4          | 2021-02-23 18:21:00.000
# 10902    | FOLKO     | 1          | 2021-02-23 16:45:00.000
# 10903    | HANAR     | 3          | 2021-02-24 17:29:00.000
# 10904    | WHITC     | 3          | 2021-02-24 13:30:00.000
# 10905    | WELLI     | 9          | 2021-02-24 15:22:00.000
# 10906    | WOLZA     | 4          | 2021-02-25 18:18:00.000
# 10907    | SPECD     | 6          | 2021-02-25 17:52:00.000
# 10908    | REGGC     | 4          | 2021-02-26 12:59:00.000
# 10909    | SANTG     | 1          | 2021-02-26 16:44:00.000
# 10910    | WILMK     | 1          | 2021-02-26 13:12:00.000
# 10911    | GODOS     | 3          | 2021-02-26 15:46:00.000
# 10912    | HUNGO     | 2          | 2021-02-26 15:49:00.000
# 10913    | QUEEN     | 4          | 2021-02-26 13:20:00.000
# 10914    | QUEEN     | 6          | 2021-02-27 14:18:00.000
# 10915    | TORTU     | 2          | 2021-02-27 18:39:00.000
# 10916    | RANCH     | 1          | 2021-02-27 18:10:00.000
# (54 rows)
#
# Total execution time: 00:00:00.012

# %%
SELECT
GETDATE() AS [GETDATE],
CURRENT_TIMESTAMP AS [CURRENT_TIMESTAMP],
GETUTCDATE() AS [GETUTCDATE],
SYSDATETIME() AS [SYSDATETIME],
SYSUTCDATETIME() AS [SYSUTCDATETIME],
SYSDATETIMEOFFSET() AS [SYSDATETIMEOFFSET];
# Out:
# (1 row affected)
#
# GETDATE                 | CURRENT_TIMESTAMP       | GETUTCDATE              | SYSDATETIME                 | SYSUTCDATETIME              | SYSDATETIMEOFFSET
# ------------------------+-------------------------+-------------------------+-----------------------------+-----------------------------+-----------------------------------
# 2026-04-23 23:21:24.620 | 2026-04-23 23:21:24.620 | 2026-04-23 23:21:24.620 | 2026-04-23 23:21:24.6385223 | 2026-04-23 23:21:24.6385223 | 2026-04-23 23:21:24.6385223 +00:00
# (1 row)
#
# Total execution time: 00:00:00.007

# %%
SELECT CAST('prueba' AS float) AS Resultado;

SET DATEFORMAT dmy;  
SELECT CAST('12/31/2010' AS datetime2) AS Resultado;  

SET DATEFORMAT mdy;  
SELECT CAST('12/31/2010' AS datetime2) AS Resultado;  

SELECT CAST(4 AS xml) AS Resultado;
# Out:
# Msg 529, Level 16, State 1, Line 9
# Explicit conversion from data type int to xml is not allowed.
# Total execution time: 00:00:00.003

# %%
SELECT CAST(10.6496 AS int) as trunc1, 
CAST(-10.6496 AS int) as trunc2, 
CAST(10.6496 AS numeric) as round1, 
CAST(-10.6496 AS numeric) as round2;
# Out:
# (1 row affected)
#
# trunc1 | trunc2 | round1 | round2
# -------+--------+--------+-------
# 10     | -10    | 11     | -11
# (1 row)
#
# Total execution time: 00:00:00.006

# %%
SELECT CAST(10.3496847 AS money); -- Redondea
# Out:
# (1 row affected)
#
# (No column name)
# ----------------
# 10.3497
# (1 row)
#
# Total execution time: 00:00:00.010

# %%
SELECT SUBSTRING(NombreProducto, 1, 30) AS NombreProd, PrecioUnitario  
FROM Productos
WHERE CAST(PrecioUnitario AS numeric) LIKE '3%'; 

SELECT SUBSTRING(NombreProducto, 1, 30) AS NombreProd, PrecioUnitario   
FROM Productos
WHERE CONVERT(numeric, PrecioUnitario) LIKE '3%';
# Out:
# (13 rows affected)
# (13 rows affected)
#
# NombreProd                     | PrecioUnitario
# -------------------------------+---------------
# Uncle Bob's Organic Dried Pear | 30.0000
# Ikura                          | 31.0000
# Queso Manchego La Pastora      | 38.0000
# Alice Mutton                   | 39.0000
# Gumbär Gummibärchen            | 31.2300
# Mascarpone Fabioli             | 32.0000
# Geitost                        | 2.5000
# Perth Pasties                  | 32.8000
# Gnocchi di nonna Alice         | 38.0000
# Camembert Pierrot              | 34.0000
# Wimmers gute Semmelknödel      | 33.2500
# Gudbrandsdalsost               | 36.0000
# Mozzarella di Giovanni         | 34.8000
# (13 rows)
#
# NombreProd                     | PrecioUnitario
# -------------------------------+---------------
# Uncle Bob's Organic Dried Pear | 30.0000
# Ikura                          | 31.0000
# Queso Manchego La Pastora      | 38.0000
# Alice Mutton                   | 39.0000
# Gumbär Gummibärchen            | 31.2300
# Mascarpone Fabioli             | 32.0000
# Geitost                        | 2.5000
# Perth Pasties                  | 32.8000
# Gnocchi di nonna Alice         | 38.0000
# Camembert Pierrot              | 34.0000
# Wimmers gute Semmelknödel      | 33.2500
# Gudbrandsdalsost               | 36.0000
# Mozzarella di Giovanni         | 34.8000
# (13 rows)
#
# Total execution time: 00:00:00.017

# %%
SELECT 'El precio es ' + 
CAST(PrecioUnitario AS varchar(12)) AS Precio  
FROM Productos 
WHERE PrecioUnitario BETWEEN 35.00 AND 40.00;
# Out:
# (5 rows affected)
#
# Precio
# --------------------
# El precio es 40.0000
# El precio es 38.0000
# El precio es 39.0000
# El precio es 38.0000
# El precio es 36.0000
# (5 rows)
#
# Total execution time: 00:00:00.019

# %%
SELECT
 GETDATE() AS FechaHoraSinConvertir,
 CAST(GETDATE() AS nvarchar(30)) AS UsandoCast,
 CONVERT(nvarchar(30), GETDATE(), 126) AS UsandoConvertA_ISO8601,
 CONVERT(nvarchar(30), GETDATE(), 101) AS UsandoConvertA_101,
 CONVERT(nvarchar(30), GETDATE(), 103) AS UsandoConvertA_103;
# Out:
# (1 row affected)
#
# FechaHoraSinConvertir   | UsandoCast          | UsandoConvertA_ISO8601  | UsandoConvertA_101 | UsandoConvertA_103
# ------------------------+---------------------+-------------------------+--------------------+-------------------
# 2026-04-23 23:21:24.773 | Apr 23 2026 11:21PM | 2026-04-23T23:21:24.773 | 04/23/2026         | 23/04/2026
# (1 row)
#
# Total execution time: 00:00:00.006

# %%
SELECT
    '2006-04-25T15:50:59.997' AS TextoSinConvertir,
    CAST('2006-04-25T15:50:59.997' AS datetime) AS UsandoCast,
    CONVERT(datetime, '2006-04-25T15:50:59.997', 126) AS UsandoConvertDe_ISO8601 ;
# Out:
# (1 row affected)
#
# TextoSinConvertir       | UsandoCast              | UsandoConvertDe_ISO8601
# ------------------------+-------------------------+------------------------
# 2006-04-25T15:50:59.997 | 2006-04-25 15:50:59.997 | 2006-04-25 15:50:59.997
# (1 row)
#
# Total execution time: 00:00:00.013

# %%
SELECT TRY_CAST('prueba' AS float)

SET DATEFORMAT dmy;  
SELECT TRY_CAST('12/31/2010' AS datetime2) AS Resultado;  

SET DATEFORMAT mdy;  
SELECT TRY_CAST('12/31/2010' AS datetime2) AS Resultado;  

SELECT TRY_CAST(4 AS xml) AS Resultado;
# Out:
# Msg 529, Level 16, State 1, Line 9
# Explicit conversion from data type int to xml is not allowed.
# Total execution time: 00:00:00.003

# %%
SELECT   
    CASE WHEN TRY_CAST('test' AS float) IS NULL   
    THEN 'Cast fallo'  
    ELSE 'Cast exito'  
END AS Resultado;
# Out:
# (1 row affected)
#
# Resultado
# ----------
# Cast fallo
# (1 row)
#
# Total execution time: 00:00:00.006

# %%
SELECT DATENAME(month, '20090212');

SELECT DATENAME(year, '20090212');
# Out:
# (1 row affected)
# (1 row affected)
#
# (No column name)
# ----------------
# February
# (1 row)
#
# (No column name)
# ----------------
# 2009
# (1 row)
#
# Total execution time: 00:00:00.010

# %%
SELECT SWITCHOFFSET(SYSDATETIMEOFFSET(), '-03:00');
SELECT SWITCHOFFSET(SYSDATETIMEOFFSET(), '+00:00');
# Out:
# (1 row affected)
# (1 row affected)
#
# (No column name)
# ----------------------------------
# 2026-04-23 20:21:24.9451356 -03:00
# (1 row)
#
# (No column name)
# ----------------------------------
# 2026-04-23 23:21:24.9451356 +00:00
# (1 row)
#
# Total execution time: 00:00:00.007

# %%
SELECT
CAST('20170212 12:00:00.0000000' AS DATETIME2)
AT TIME ZONE 'Argentina Standard Time' AS val1,
CAST('20170212 12:00:00.0000000' AS DATETIME2)
AT TIME ZONE 'Pacific Standard Time' AS val2;
# Out:
# (1 row affected)
#
# val1                               | val2
# -----------------------------------+-----------------------------------
# 2017-02-12 12:00:00.0000000 -03:00 | 2017-02-12 12:00:00.0000000 -08:00
# (1 row)
#
# Total execution time: 00:00:02.993

# %%
SELECT DATEADD(year, 1, '20090212');
# Out:
# (1 row affected)
#
# (No column name)
# -----------------------
# 2010-02-12 00:00:00.000
# (1 row)
#
# Total execution time: 00:00:00.014

# %%
SELECT DATEDIFF(day, '20080212', '20090212');
SELECT DATEDIFF_BIG(millisecond, '00010101', '20160212');
# Out:
# (1 row affected)
# (1 row affected)
#
# (No column name)
# ----------------
# 366
# (1 row)
#
# (No column name)
# ----------------
# 63590832000000
# (1 row)
#
# Total execution time: 00:00:00.014

# %%
SELECT DATEADD( day, 
DATEDIFF(day, '19000101', SYSDATETIME()), '19000101');
# Out:
# (1 row affected)
#
# (No column name)
# -----------------------
# 2026-04-23 00:00:00.000
# (1 row)
#
# Total execution time: 00:00:00.009

# %%
SELECT DATETIMEFROMPARTS(YEAR(SYSDATETIME()), MONTH(SYSDATETIME()), DAY(SYSDATETIME()), 0, 0, 0, 0);
# Out:
# (1 row affected)
#
# (No column name)
# -----------------------
# 2026-04-23 00:00:00.000
# (1 row)
#
# Total execution time: 00:00:00.008

# %%
DECLARE @d datetime2 = SYSDATETIME();
SELECT 'Año', DATETRUNC(year, @d);
SELECT 'Trimestre', DATETRUNC(quarter, @d);
SELECT 'Mes', DATETRUNC(month, @d);
SELECT 'Semana', DATETRUNC(week, @d);
SELECT 'Iso_Semana', DATETRUNC(iso_week, @d);
SELECT 'Dia', DATETRUNC(day, @d);
SELECT 'Hora', DATETRUNC(hour, @d);
SELECT 'Minuto', DATETRUNC(minute, @d);
SELECT 'Segundo', DATETRUNC(second, @d);
SELECT 'Milisegundo', DATETRUNC(millisecond, @d);
SELECT 'Microsegundo', DATETRUNC(microsecond, @d);
# Out:
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
# (1 row affected)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Año              | 2026-01-01 00:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Trimestre        | 2026-04-01 00:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Mes              | 2026-04-01 00:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Semana           | 2026-04-19 00:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Iso_Semana       | 2026-04-20 00:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Dia              | 2026-04-23 00:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Hora             | 2026-04-23 23:00:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Minuto           | 2026-04-23 23:21:00.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Segundo          | 2026-04-23 23:21:28.0000000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Milisegundo      | 2026-04-23 23:21:28.2750000
# (1 row)
#
# (No column name) | (No column name)
# -----------------+----------------------------
# Microsegundo     | 2026-04-23 23:21:28.2750460
# (1 row)
#
# Total execution time: 00:00:00.186

# %%
SELECT DATE_BUCKET(DAY,1,SYSDATETIME());
# Out:
# (1 row affected)
#
# (No column name)
# ---------------------------
# 2026-04-23 00:00:00.0000000
# (1 row)
#
# Total execution time: 00:00:00.006

# %%
SELECT ISDATE('20090212');

SELECT ISDATE('20090230');
# Out:
# (1 row affected)
# (1 row affected)
#
# (No column name)
# ----------------
# 1
# (1 row)
#
# (No column name)
# ----------------
# 0
# (1 row)
#
# Total execution time: 00:00:00.012

# %%
SELECT EOMONTH(SYSDATETIME());
# Out:
# (1 row affected)
#
# (No column name)
# ----------------
# 2026-04-30
# (1 row)
#
# Total execution time: 00:00:00.006
