# %% [markdown]
# # Unidad 01

# %% [markdown]
# ## TOP

# %%
SELECT TOP (4) IDPedido, FechaEnvio, IDCliente, IDEmpleado
FROM Pedidos
ORDER BY FechaEnvio DESC;
# Out:
# (4 rows affected)
# IDPedido | FechaEnvio              | IDCliente | IDEmpleado
# ---------+-------------------------+-----------+-----------
# 11069    | 2021-05-06 00:00:00.000 | TORTU     | 1
# 11067    | 2021-05-06 00:00:00.000 | DRACD     | 1
# 11063    | 2021-05-06 00:00:00.000 | HUNGO     | 3
# 11055    | 2021-05-05 00:00:00.000 | HILAA     | 7
# (4 rows)

# %%
SELECT TOP (1) PERCENT IDPedido, FechaEnvio, IDCliente, IDEmpleado
FROM Pedidos
ORDER BY FechaEnvio DESC;
# Out:
# (9 rows affected)
# IDPedido | FechaEnvio              | IDCliente | IDEmpleado
# ---------+-------------------------+-----------+-----------
# 11069    | 2021-05-06 00:00:00.000 | TORTU     | 1
# 11063    | 2021-05-06 00:00:00.000 | HUNGO     | 3
# 11067    | 2021-05-06 00:00:00.000 | DRACD     | 1
# 11050    | 2021-05-05 00:00:00.000 | FOLKO     | 8
# 11055    | 2021-05-05 00:00:00.000 | HILAA     | 7
# 11060    | 2021-05-04 00:00:00.000 | FRANS     | 2
# 11049    | 2021-05-04 00:00:00.000 | GOURL     | 3
# 11064    | 2021-05-04 00:00:00.000 | SAVEA     | 1
# 11066    | 2021-05-04 00:00:00.000 | WHITC     | 7
# (9 rows)

# %%
SELECT TOP (4) IDPedido, FechaEnvio, IDCliente, IDEmpleado
FROM Pedidos
ORDER BY FechaEnvio DESC, IDPedido DESC;
# Out:
# (4 rows affected)
# IDPedido | FechaEnvio              | IDCliente | IDEmpleado
# ---------+-------------------------+-----------+-----------
# 11069    | 2021-05-06 00:00:00.000 | TORTU     | 1
# 11067    | 2021-05-06 00:00:00.000 | DRACD     | 1
# 11063    | 2021-05-06 00:00:00.000 | HUNGO     | 3
# 11055    | 2021-05-05 00:00:00.000 | HILAA     | 7
# (4 rows)

# %%
SELECT TOP (1) PERCENT IDPedido, FechaEnvio, IDCliente, IDEmpleado
FROM Pedidos
ORDER BY FechaEnvio DESC, IDPedido DESC;
# Out:
# (9 rows affected)
# IDPedido | FechaEnvio              | IDCliente | IDEmpleado
# ---------+-------------------------+-----------+-----------
# 11069    | 2021-05-06 00:00:00.000 | TORTU     | 1
# 11067    | 2021-05-06 00:00:00.000 | DRACD     | 1
# 11063    | 2021-05-06 00:00:00.000 | HUNGO     | 3
# 11055    | 2021-05-05 00:00:00.000 | HILAA     | 7
# 11050    | 2021-05-05 00:00:00.000 | FOLKO     | 8
# 11066    | 2021-05-04 00:00:00.000 | WHITC     | 7
# 11064    | 2021-05-04 00:00:00.000 | SAVEA     | 1
# 11060    | 2021-05-04 00:00:00.000 | FRANS     | 2
# 11049    | 2021-05-04 00:00:00.000 | GOURL     | 3
# (9 rows)

# %%
DROP TABLE IF EXISTS #podio;

CREATE TABLE #podio ( 
nombre nvarchar(50) PRIMARY KEY, 
pais nvarchar(50), 
tiempo numeric(18,2) 
); 

INSERT INTO #podio (nombre, pais, tiempo)
VALUES 
('Aleksandr Sadovnikov', 'RUS', 51.84),
('Chad Le Clos', 'RSA', 51.14),
('Joseph Schooling', 'SGP', 50.39),
('Laszlo Cseh', 'HUN', 51.14),
('Medhy Metella', 'FRA', 51.58),
('Michael Phelps', 'USA', 51.14),
('Tom Shields', 'USA', 51.73),
('Zhuhao Li', 'CHN', 51.26);

SELECT TOP (3) nombre, pais, tiempo FROM #podio ORDER BY tiempo ASC;
# Out:
# (8 rows affected)
# (3 rows affected)
# nombre           | pais | tiempo
# -----------------+------+-------
# Joseph Schooling | SGP  | 50.39
# Laszlo Cseh      | HUN  | 51.14
# Chad Le Clos     | RSA  | 51.14
# (3 rows)

# %% [markdown]
# ### WITH TIES

# %%
DROP TABLE IF EXISTS #podio;

CREATE TABLE #podio ( 
nombre nvarchar(50) PRIMARY KEY, 
pais nvarchar(50), 
tiempo numeric(18,2) 
); 

INSERT INTO #podio (nombre, pais, tiempo)
VALUES 
('Aleksandr Sadovnikov', 'RUS', 51.84),
('Chad Le Clos', 'RSA', 51.14),
('Joseph Schooling', 'SGP', 50.39),
('Laszlo Cseh', 'HUN', 51.14),
('Medhy Metella', 'FRA', 51.58),
('Michael Phelps', 'USA', 51.14),
('Tom Shields', 'USA', 51.73),
('Zhuhao Li', 'CHN', 51.26);

SELECT TOP (3) WITH TIES nombre, pais, tiempo FROM #podio ORDER BY tiempo ASC;
# Out:
# (8 rows affected)
# (4 rows affected)
# nombre           | pais | tiempo
# -----------------+------+-------
# Joseph Schooling | SGP  | 50.39
# Laszlo Cseh      | HUN  | 51.14
# Chad Le Clos     | RSA  | 51.14
# Michael Phelps   | USA  | 51.14
# (4 rows)

# %%
SELECT TOP (4) WITH TIES IDPedido, FechaEnvio, IDCliente, IDEmpleado
FROM Pedidos
ORDER BY FechaEnvio DESC;
# Out:
# (5 rows affected)
# IDPedido | FechaEnvio              | IDCliente | IDEmpleado
# ---------+-------------------------+-----------+-----------
# 11069    | 2021-05-06 00:00:00.000 | TORTU     | 1
# 11067    | 2021-05-06 00:00:00.000 | DRACD     | 1
# 11063    | 2021-05-06 00:00:00.000 | HUNGO     | 3
# 11055    | 2021-05-05 00:00:00.000 | HILAA     | 7
# 11050    | 2021-05-05 00:00:00.000 | FOLKO     | 8
# (5 rows)

# %% [markdown]
# ## OFFSET FETCH

# %%
SELECT IDPedido, FechaEnvio, IDCliente, IDEmpleado
FROM Pedidos
ORDER BY FechaEnvio, IDPedido
OFFSET 50 ROWS FETCH NEXT 25 ROWS ONLY;
# Out:
# (25 rows affected)
# IDPedido | FechaEnvio              | IDCliente | IDEmpleado
# ---------+-------------------------+-----------+-----------
# 10279    | 2019-08-16 00:00:00.000 | LEHMS     | 8
# 10281    | 2019-08-21 00:00:00.000 | ROMEY     | 4
# 10282    | 2019-08-21 00:00:00.000 | ROMEY     | 4
# 10264    | 2019-08-23 00:00:00.000 | FOLKO     | 6
# 10283    | 2019-08-23 00:00:00.000 | LILAS     | 3
# 10285    | 2019-08-26 00:00:00.000 | QUICK     | 1
# 10284    | 2019-08-27 00:00:00.000 | LEHMS     | 4
# 10287    | 2019-08-28 00:00:00.000 | RICAR     | 8
# 10289    | 2019-08-28 00:00:00.000 | BSBEV     | 7
# 10271    | 2019-08-30 00:00:00.000 | SPLIR     | 6
# 10286    | 2019-08-30 00:00:00.000 | QUICK     | 8
# 10292    | 2019-09-02 00:00:00.000 | TRADH     | 1
# 10288    | 2019-09-03 00:00:00.000 | REGGC     | 4
# 10290    | 2019-09-03 00:00:00.000 | COMMI     | 8
# 10291    | 2019-09-04 00:00:00.000 | QUEDE     | 6
# 10294    | 2019-09-05 00:00:00.000 | RATTC     | 4
# 10295    | 2019-09-10 00:00:00.000 | VINET     | 2
# 10297    | 2019-09-10 00:00:00.000 | BLONP     | 5
# 10293    | 2019-09-11 00:00:00.000 | TORTU     | 1
# 10296    | 2019-09-11 00:00:00.000 | LILAS     | 6
# 10298    | 2019-09-11 00:00:00.000 | HUNGO     | 6
# 10280    | 2019-09-12 00:00:00.000 | BERGS     | 2
# 10299    | 2019-09-13 00:00:00.000 | RICAR     | 4
# 10301    | 2019-09-17 00:00:00.000 | WANDK     | 8
# 10304    | 2019-09-17 00:00:00.000 | TORTU     | 1
# (25 rows)

# %% [markdown]
# ## IN

# %%
SELECT IDPedido, IDEmpleado, FechaPedido
FROM Pedidos
WHERE IDPedido IN(10248, 10249, 10250);
# Out:
# (3 rows affected)
# IDPedido | IDEmpleado | FechaPedido
# ---------+------------+------------------------
# 10248    | 5          | 2019-07-04 16:58:00.000
# 10249    | 6          | 2019-07-05 18:17:00.000
# 10250    | 4          | 2019-07-08 14:38:00.000
# (3 rows)

# %% [markdown]
# ## BETWEEN

# %%
SELECT IDPedido, IDEmpleado, FechaPedido
FROM Pedidos
WHERE IDPedido BETWEEN 10300 AND 10310;
# Out:
# (11 rows affected)
# IDPedido | IDEmpleado | FechaPedido
# ---------+------------+------------------------
# 10300    | 2          | 2019-09-09 12:14:00.000
# 10301    | 8          | 2019-09-09 16:39:00.000
# 10302    | 4          | 2019-09-10 18:37:00.000
# 10303    | 7          | 2019-09-11 14:12:00.000
# 10304    | 1          | 2019-09-12 16:46:00.000
# 10305    | 8          | 2019-09-13 18:27:00.000
# 10306    | 1          | 2019-09-16 18:43:00.000
# 10307    | 2          | 2019-09-17 17:44:00.000
# 10308    | 7          | 2019-09-18 13:10:00.000
# 10309    | 3          | 2019-09-19 14:46:00.000
# 10310    | 8          | 2019-09-20 15:54:00.000
# (11 rows)

# %% [markdown]
# ## LIKE

# %%
SELECT IDEmpleado, Nombre, Apellido
FROM Empleados
WHERE Apellido LIKE 'D%';
# Out:
# (2 rows affected)
# IDEmpleado | Nombre | Apellido
# -----------+--------+----------
# 1          | Nancy  | Davolio
# 9          | Anne   | Dodsworth
# (2 rows)

# %% [markdown]
# ## Operadores Aritméticos

# %%
SELECT TOP (10)IDPedido, IDProducto, Cantidad, PrecioUnitario, Descuento,
Cantidad * PrecioUnitario * (1 - Descuento) AS valorneto
FROM [Detalles Pedido];
# Out:
# (10 rows affected)
# IDPedido | IDProducto | Cantidad | PrecioUnitario | Descuento | valorneto
# ---------+------------+----------+----------------+-----------+-------------
# 10248    | 11         | 12       | 14.0000        | 0.000     | 168.0000000
# 10248    | 42         | 10       | 9.8000         | 0.000     | 98.0000000
# 10248    | 72         | 5        | 34.8000        | 0.000     | 174.0000000
# 10249    | 14         | 9        | 18.6000        | 0.000     | 167.4000000
# 10249    | 51         | 40       | 42.4000        | 0.000     | 1696.0000000
# 10250    | 41         | 10       | 7.7000         | 0.000     | 77.0000000
# 10250    | 51         | 35       | 42.4000        | 0.150     | 1261.4000000
# 10250    | 65         | 15       | 16.8000        | 0.150     | 214.2000000
# 10251    | 22         | 6        | 16.8000        | 0.050     | 95.7600000
# 10251    | 57         | 15       | 15.6000        | 0.050     | 222.3000000
# (10 rows)

# %%
SELECT 5/2
# Out:
# (1 row affected)
# (No column name)
# ----------------
# 2
# (1 row)

# %%
SELECT 5/2.0
# Out:
# (1 row affected)
# (No column name)
# ----------------
# 2.500000
# (1 row)

# %% [markdown]
# ## Precedencia

# %%
SELECT IDPedido, IDCliente, 
IDEmpleado, FechaPedido
FROM Pedidos
WHERE IDCliente = 'ALFKI' 
AND IDEmpleado IN(1, 3, 5) 
OR IDCliente = 'VINET' 
AND IDEmpleado IN(2, 4, 6);
# Out:
# (6 rows affected)
# IDPedido | IDCliente | IDEmpleado | FechaPedido
# ---------+-----------+------------+------------------------
# 10274    | VINET     | 6          | 2019-08-06 12:21:00.000
# 10295    | VINET     | 2          | 2019-09-02 13:32:00.000
# 10737    | VINET     | 2          | 2020-11-11 17:45:00.000
# 10835    | ALFKI     | 1          | 2021-01-15 13:18:00.000
# 10952    | ALFKI     | 1          | 2021-03-16 16:30:00.000
# 11011    | ALFKI     | 3          | 2021-04-09 15:46:00.000
# (6 rows)

# %% [markdown]
# ## CASE

# %%
SELECT TOP(10) IDProducto, NombreProducto, IDCategoria,
CASE IDCategoria
WHEN 1 THEN 'Bebidas'
WHEN 2 THEN 'Condimentos'
WHEN 3 THEN 'Confites'
WHEN 4 THEN 'Lacteos'
WHEN 5 THEN 'Granos/Cereales'
WHEN 6 THEN 'Avicola'
WHEN 7 THEN 'Frutas'
WHEN 8 THEN 'Mariscos'
ELSE 'Categoria Desconocida'
END AS NombreCategoria
FROM Productos
# Out:
# (10 rows affected)
# IDProducto | NombreProducto                  | IDCategoria | NombreCategoria
# -----------+---------------------------------+-------------+----------------
# 1          | Chai                            | 1           | Bebidas
# 2          | Chang                           | 1           | Bebidas
# 3          | Aniseed Syrup                   | 2           | Condimentos
# 4          | Chef Anton's Cajun Seasoning    | 2           | Condimentos
# 5          | Chef Anton's Gumbo Mix          | 2           | Condimentos
# 6          | Grandma's Boysenberry Spread    | 2           | Condimentos
# 7          | Uncle Bob's Organic Dried Pears | 7           | Frutas
# 8          | Northwoods Cranberry Sauce      | 2           | Condimentos
# 9          | Mishi Kobe Niku                 | 6           | Avicola
# 10         | Ikura                           | 8           | Mariscos
# (10 rows)

# %%
SELECT TOP(10) IDPedido, IDCliente, val,
CASE
WHEN val < 1000.00 THEN 'Menos de 1000'
WHEN val BETWEEN 1000.00 AND 3000.00 THEN 'Entre 1000 y 3000'
WHEN val > 3000.00 THEN 'Mas de 3000'
ELSE 'Desconocido'
END AS CategoriaValor
FROM ValoresPedido
# Out:
# (10 rows affected)
# IDPedido | IDCliente | val     | CategoriaValor
# ---------+-----------+---------+------------------
# 10248    | VINET     | 440.00  | Menos de 1000
# 10249    | TOMSP     | 1863.40 | Entre 1000 y 3000
# 10250    | HANAR     | 1552.60 | Entre 1000 y 3000
# 10251    | VICTE     | 654.06  | Menos de 1000
# 10252    | SUPRD     | 3597.90 | Mas de 3000
# 10253    | HANAR     | 1444.80 | Entre 1000 y 3000
# 10254    | CHOPS     | 556.62  | Menos de 1000
# 10255    | RICSU     | 2490.50 | Entre 1000 y 3000
# 10256    | WELLI     | 517.80  | Menos de 1000
# 10257    | HILAA     | 1119.90 | Entre 1000 y 3000
# (10 rows)

# %% [markdown]
# ## GREATEST y LEAST

# %%
SELECT IDPedido, FechaRequerida, FechaEnvio,
GREATEST(FechaRequerida, FechaEnvio) AS fechatardia,
LEAST(Fecharequerida, FechaEnvio) AS fechatemprana
FROM Pedidos
WHERE IDCliente = 'BOLID';
# Out:
# (3 rows affected)
# IDPedido | FechaRequerida          | FechaEnvio              | fechatardia             | fechatemprana
# ---------+-------------------------+-------------------------+-------------------------+------------------------
# 10326    | 2019-11-07 00:00:00.000 | 2019-10-14 00:00:00.000 | 2019-11-07 00:00:00.000 | 2019-10-14 00:00:00.000
# 10801    | 2021-01-26 00:00:00.000 | 2020-12-31 00:00:00.000 | 2021-01-26 00:00:00.000 | 2020-12-31 00:00:00.000
# 10970    | 2021-04-07 00:00:00.000 | 2021-04-24 00:00:00.000 | 2021-04-24 00:00:00.000 | 2021-04-07 00:00:00.000
# (3 rows)

# %% [markdown]
# ## Filtrando Region

# %%
SELECT IDCliente, Pais, Region, Ciudad
FROM Clientes;
# Out:
# (91 rows affected)
# IDCliente | Pais        | Region        | Ciudad
# ----------+-------------+---------------+----------------
# ALFKI     | Alemania    | NULL          | Berlin
# ANATR     | Mexico      | NULL          | México D.F.
# ANTON     | Mexico      | NULL          | México D.F.
# AROUT     | Reino Unido | NULL          | London
# BERGS     | Suecia      | NULL          | Luleå
# BLAUS     | Alemania    | NULL          | Mannheim
# BLONP     | Francia     | NULL          | Strasbourg
# BOLID     | España      | NULL          | Madrid
# BONAP     | Francia     | NULL          | Marseille
# BOTTM     | Canadá      | BC            | Tsawassen
# BSBEV     | Reino Unido | NULL          | London
# CACTU     | Argentina   | NULL          | Buenos Aires
# CENTC     | Mexico      | NULL          | México D.F.
# CHOPS     | Suiza       | NULL          | Bern
# COMMI     | Brasil      | SP            | Sao Paulo
# CONSH     | Reino Unido | NULL          | London
# DRACD     | Alemania    | NULL          | Aachen
# DUMON     | Francia     | NULL          | Nantes
# EASTC     | Reino Unido | NULL          | London
# ERNSH     | Austria     | NULL          | Graz
# FAMIA     | Brasil      | SP            | Sao Paulo
# FISSA     | España      | NULL          | Madrid
# FOLIG     | Francia     | NULL          | Lille
# FOLKO     | Suecia      | NULL          | Bräcke
# FRANK     | Alemania    | NULL          | München
# FRANR     | Francia     | NULL          | Nantes
# FRANS     | Italia      | NULL          | Torino
# FURIB     | Portugal    | NULL          | Lisboa
# GALED     | España      | NULL          | Barcelona
# GODOS     | España      | NULL          | Sevilla
# GOURL     | Brasil      | SP            | Campinas
# GREAL     | EE.UU.      | OR            | Eugene
# GROSR     | Venezuela   | DF            | Caracas
# HANAR     | Brasil      | RJ            | Rio de Janeiro
# HILAA     | Venezuela   | Táchira       | San Cristóbal
# HUNGC     | EE.UU.      | OR            | Elgin
# HUNGO     | Irlanda     | Co. Cork      | Cork
# ISLAT     | Reino Unido | Isle of Wight | Cowes
# KOENE     | Alemania    | NULL          | Brandenburg
# LACOR     | Francia     | NULL          | Versailles
# LAMAI     | Francia     | NULL          | Toulouse
# LAUGB     | Canadá      | BC            | Vancouver
# LAZYK     | EE.UU.      | WA            | Walla Walla
# LEHMS     | Alemania    | NULL          | Frankfurt a.M.
# LETSS     | EE.UU.      | CA            | San Francisco
# LILAS     | Venezuela   | Lara          | Barquisimeto
# LINOD     | Venezuela   | Nueva Esparta | I. de Margarita
# LONEP     | EE.UU.      | OR            | Portland
# MAGAA     | Italia      | NULL          | Bergamo
# MAISD     | Bélgica     | NULL          | Bruxelles
# MEREP     | Canadá      | Québec        | Montréal
# MORGK     | Alemania    | NULL          | Leipzig
# NORTS     | Reino Unido | NULL          | London
# OCEAN     | Argentina   | NULL          | Buenos Aires
# OLDWO     | EE.UU.      | AK            | Anchorage
# OTTIK     | Alemania    | NULL          | Köln
# PARIS     | Francia     | NULL          | Paris
# PERIC     | Mexico      | NULL          | México D.F.
# PICCO     | Austria     | NULL          | Salzburg
# PRINI     | Portugal    | NULL          | Lisboa
# QUEDE     | Brasil      | RJ            | Rio de Janeiro
# QUEEN     | Brasil      | SP            | Sao Paulo
# QUICK     | Alemania    | NULL          | Cunewalde
# RANCH     | Argentina   | NULL          | Buenos Aires
# RATTC     | EE.UU.      | NM            | Albuquerque
# REGGC     | Italia      | NULL          | Reggio Emilia
# RICAR     | Brasil      | RJ            | Rio de Janeiro
# RICSU     | Suiza       | NULL          | Genève
# ROMEY     | España      | NULL          | Madrid
# SANTG     | Noruega     | NULL          | Stavern
# SAVEA     | EE.UU.      | ID            | Boise
# SEVES     | Reino Unido | NULL          | London
# SIMOB     | Dinamarca   | NULL          | Kobenhavn
# SPECD     | Francia     | NULL          | Paris
# SPLIR     | EE.UU.      | WY            | Lander
# SUPRD     | Bélgica     | NULL          | Charleroi
# THEBI     | EE.UU.      | OR            | Portland
# THECR     | EE.UU.      | MT            | Butte
# TOMSP     | Alemania    | NULL          | Münster
# TORTU     | Mexico      | NULL          | México D.F.
# TRADH     | Brasil      | SP            | Sao Paulo
# TRAIH     | EE.UU.      | WA            | Kirkland
# VAFFE     | Dinamarca   | NULL          | Århus
# VICTE     | Francia     | NULL          | Lyon
# VINET     | Francia     | NULL          | Reims
# WANDK     | Alemania    | NULL          | Stuttgart
# WARTH     | Finlandia   | NULL          | Oulu
# WELLI     | Brasil      | SP            | Resende
# WHITC     | EE.UU.      | WA            | Seattle
# WILMK     | Finlandia   | NULL          | Helsinki
# WOLZA     | Polonia     | NULL          | Warszawa
# (91 rows)

# %%
SELECT IDCliente, Pais, Region, Ciudad
FROM Clientes
WHERE Region = 'WA';
# Out:
# (3 rows affected)
# IDCliente | Pais   | Region | Ciudad
# ----------+--------+--------+------------
# LAZYK     | EE.UU. | WA     | Walla Walla
# TRAIH     | EE.UU. | WA     | Kirkland
# WHITC     | EE.UU. | WA     | Seattle
# (3 rows)

# %%
SELECT IDCliente, Pais, Region, Ciudad
FROM Clientes
WHERE Region <> 'WA';
# Out:
# (28 rows affected)
# IDCliente | Pais        | Region        | Ciudad
# ----------+-------------+---------------+----------------
# BOTTM     | Canadá      | BC            | Tsawassen
# COMMI     | Brasil      | SP            | Sao Paulo
# FAMIA     | Brasil      | SP            | Sao Paulo
# GOURL     | Brasil      | SP            | Campinas
# GREAL     | EE.UU.      | OR            | Eugene
# GROSR     | Venezuela   | DF            | Caracas
# HANAR     | Brasil      | RJ            | Rio de Janeiro
# HILAA     | Venezuela   | Táchira       | San Cristóbal
# HUNGC     | EE.UU.      | OR            | Elgin
# HUNGO     | Irlanda     | Co. Cork      | Cork
# ISLAT     | Reino Unido | Isle of Wight | Cowes
# LAUGB     | Canadá      | BC            | Vancouver
# LETSS     | EE.UU.      | CA            | San Francisco
# LILAS     | Venezuela   | Lara          | Barquisimeto
# LINOD     | Venezuela   | Nueva Esparta | I. de Margarita
# LONEP     | EE.UU.      | OR            | Portland
# MEREP     | Canadá      | Québec        | Montréal
# OLDWO     | EE.UU.      | AK            | Anchorage
# QUEDE     | Brasil      | RJ            | Rio de Janeiro
# QUEEN     | Brasil      | SP            | Sao Paulo
# RATTC     | EE.UU.      | NM            | Albuquerque
# RICAR     | Brasil      | RJ            | Rio de Janeiro
# SAVEA     | EE.UU.      | ID            | Boise
# SPLIR     | EE.UU.      | WY            | Lander
# THEBI     | EE.UU.      | OR            | Portland
# THECR     | EE.UU.      | MT            | Butte
# TRADH     | Brasil      | SP            | Sao Paulo
# WELLI     | Brasil      | SP            | Resende
# (28 rows)

# %% [markdown]
# ## IS [NOT] DISTINCT FROM

# %%
SELECT IDCliente, Pais, Region, Ciudad
FROM Clientes
WHERE Region IS NOT DISTINCT FROM 'WA';
# Out:
# (3 rows affected)
# IDCliente | Pais   | Region | Ciudad
# ----------+--------+--------+------------
# LAZYK     | EE.UU. | WA     | Walla Walla
# TRAIH     | EE.UU. | WA     | Kirkland
# WHITC     | EE.UU. | WA     | Seattle
# (3 rows)

# %%
SELECT IDCliente, Pais, Region, Ciudad
FROM Clientes
WHERE Region IS DISTINCT FROM 'WA';
# Out:
# (88 rows affected)
# IDCliente | Pais        | Region        | Ciudad
# ----------+-------------+---------------+----------------
# ALFKI     | Alemania    | NULL          | Berlin
# ANATR     | Mexico      | NULL          | México D.F.
# ANTON     | Mexico      | NULL          | México D.F.
# AROUT     | Reino Unido | NULL          | London
# BERGS     | Suecia      | NULL          | Luleå
# BLAUS     | Alemania    | NULL          | Mannheim
# BLONP     | Francia     | NULL          | Strasbourg
# BOLID     | España      | NULL          | Madrid
# BONAP     | Francia     | NULL          | Marseille
# BOTTM     | Canadá      | BC            | Tsawassen
# BSBEV     | Reino Unido | NULL          | London
# CACTU     | Argentina   | NULL          | Buenos Aires
# CENTC     | Mexico      | NULL          | México D.F.
# CHOPS     | Suiza       | NULL          | Bern
# COMMI     | Brasil      | SP            | Sao Paulo
# CONSH     | Reino Unido | NULL          | London
# DRACD     | Alemania    | NULL          | Aachen
# DUMON     | Francia     | NULL          | Nantes
# EASTC     | Reino Unido | NULL          | London
# ERNSH     | Austria     | NULL          | Graz
# FAMIA     | Brasil      | SP            | Sao Paulo
# FISSA     | España      | NULL          | Madrid
# FOLIG     | Francia     | NULL          | Lille
# FOLKO     | Suecia      | NULL          | Bräcke
# FRANK     | Alemania    | NULL          | München
# FRANR     | Francia     | NULL          | Nantes
# FRANS     | Italia      | NULL          | Torino
# FURIB     | Portugal    | NULL          | Lisboa
# GALED     | España      | NULL          | Barcelona
# GODOS     | España      | NULL          | Sevilla
# GOURL     | Brasil      | SP            | Campinas
# GREAL     | EE.UU.      | OR            | Eugene
# GROSR     | Venezuela   | DF            | Caracas
# HANAR     | Brasil      | RJ            | Rio de Janeiro
# HILAA     | Venezuela   | Táchira       | San Cristóbal
# HUNGC     | EE.UU.      | OR            | Elgin
# HUNGO     | Irlanda     | Co. Cork      | Cork
# ISLAT     | Reino Unido | Isle of Wight | Cowes
# KOENE     | Alemania    | NULL          | Brandenburg
# LACOR     | Francia     | NULL          | Versailles
# LAMAI     | Francia     | NULL          | Toulouse
# LAUGB     | Canadá      | BC            | Vancouver
# LEHMS     | Alemania    | NULL          | Frankfurt a.M.
# LETSS     | EE.UU.      | CA            | San Francisco
# LILAS     | Venezuela   | Lara          | Barquisimeto
# LINOD     | Venezuela   | Nueva Esparta | I. de Margarita
# LONEP     | EE.UU.      | OR            | Portland
# MAGAA     | Italia      | NULL          | Bergamo
# MAISD     | Bélgica     | NULL          | Bruxelles
# MEREP     | Canadá      | Québec        | Montréal
# MORGK     | Alemania    | NULL          | Leipzig
# NORTS     | Reino Unido | NULL          | London
# OCEAN     | Argentina   | NULL          | Buenos Aires
# OLDWO     | EE.UU.      | AK            | Anchorage
# OTTIK     | Alemania    | NULL          | Köln
# PARIS     | Francia     | NULL          | Paris
# PERIC     | Mexico      | NULL          | México D.F.
# PICCO     | Austria     | NULL          | Salzburg
# PRINI     | Portugal    | NULL          | Lisboa
# QUEDE     | Brasil      | RJ            | Rio de Janeiro
# QUEEN     | Brasil      | SP            | Sao Paulo
# QUICK     | Alemania    | NULL          | Cunewalde
# RANCH     | Argentina   | NULL          | Buenos Aires
# RATTC     | EE.UU.      | NM            | Albuquerque
# REGGC     | Italia      | NULL          | Reggio Emilia
# RICAR     | Brasil      | RJ            | Rio de Janeiro
# RICSU     | Suiza       | NULL          | Genève
# ROMEY     | España      | NULL          | Madrid
# SANTG     | Noruega     | NULL          | Stavern
# SAVEA     | EE.UU.      | ID            | Boise
# SEVES     | Reino Unido | NULL          | London
# SIMOB     | Dinamarca   | NULL          | Kobenhavn
# SPECD     | Francia     | NULL          | Paris
# SPLIR     | EE.UU.      | WY            | Lander
# SUPRD     | Bélgica     | NULL          | Charleroi
# THEBI     | EE.UU.      | OR            | Portland
# THECR     | EE.UU.      | MT            | Butte
# TOMSP     | Alemania    | NULL          | Münster
# TORTU     | Mexico      | NULL          | México D.F.
# TRADH     | Brasil      | SP            | Sao Paulo
# VAFFE     | Dinamarca   | NULL          | Århus
# VICTE     | Francia     | NULL          | Lyon
# VINET     | Francia     | NULL          | Reims
# WANDK     | Alemania    | NULL          | Stuttgart
# WARTH     | Finlandia   | NULL          | Oulu
# WELLI     | Brasil      | SP            | Resende
# WILMK     | Finlandia   | NULL          | Helsinki
# WOLZA     | Polonia     | NULL          | Warszawa
# (88 rows)

# %% [markdown]
# ## Operaciones Simultáneas

# %%
SELECT
IDPedido,
YEAR(FechaPedido) AS anioorden,
anioorden + 1 AS aniosiguiente
FROM Pedidos;
# Out:
# (Command completed successfully)

# %% [markdown]
# ## Collation

# %%
SELECT TOP(10) name, description
FROM sys.fn_helpcollations();
# Out:
# (10 rows affected)
# name                 | description
# ---------------------+----------------------------------------------------------------------------------------
# Albanian_BIN         | Albanian, binary sort
# Albanian_BIN2        | Albanian, binary code point comparison sort
# Albanian_CI_AI       | Albanian, case-insensitive, accent-insensitive, kanatype-insensitive, width-insensitive
# Albanian_CI_AI_WS    | Albanian, case-insensitive, accent-insensitive, kanatype-insensitive, width-sensitive
# Albanian_CI_AI_KS    | Albanian, case-insensitive, accent-insensitive, kanatype-sensitive, width-insensitive
# Albanian_CI_AI_KS_WS | Albanian, case-insensitive, accent-insensitive, kanatype-sensitive, width-sensitive
# Albanian_CI_AS       | Albanian, case-insensitive, accent-sensitive, kanatype-insensitive, width-insensitive
# Albanian_CI_AS_WS    | Albanian, case-insensitive, accent-sensitive, kanatype-insensitive, width-sensitive
# Albanian_CI_AS_KS    | Albanian, case-insensitive, accent-sensitive, kanatype-sensitive, width-insensitive
# Albanian_CI_AS_KS_WS | Albanian, case-insensitive, accent-sensitive, kanatype-sensitive, width-sensitive
# (10 rows)

# %%
SELECT IDCliente, NombreEmpresa
FROM Clientes
ORDER BY IDCliente
OFFSET 13 ROWS FETCH NEXT 1 ROWS ONLY;
# Out:
# (1 row affected)
# IDCliente | NombreEmpresa
# ----------+------------------
# CHOPS     | Chop-suey Chinese
# (1 row)

# %%
SELECT IDCliente, NombreEmpresa
FROM Clientes
ORDER BY IDCliente COLLATE Traditional_Spanish_100_CI_AI_SC_UTF8
OFFSET 13 ROWS FETCH NEXT 1 ROWS ONLY;
# Out:
# (1 row affected)
# IDCliente | NombreEmpresa
# ----------+-----------------
# COMMI     | Comércio Mineiro
# (1 row)

# %%
SELECT IDCliente, NombreEmpresa, OrdMod, OrdTrad
FROM (SELECT IDCliente, NombreEmpresa,
ROW_NUMBER() OVER 
(ORDER BY IDCliente COLLATE Traditional_Spanish_100_CI_AI_SC_UTF8) AS OrdTrad,
ROW_NUMBER() OVER 
(ORDER BY IDCliente COLLATE Modern_Spanish_100_CI_AI_SC_UTF8) AS OrdMod
FROM Clientes) AS D
WHERE OrdMod <> OrdTrad;
# Out:
# (3 rows affected)
# IDCliente | NombreEmpresa         | OrdMod | OrdTrad
# ----------+-----------------------+--------+--------
# CHOPS     | Chop-suey Chinese     | 14     | 16
# COMMI     | Comércio Mineiro      | 15     | 14
# CONSH     | Consolidated Holdings | 16     | 15
# (3 rows)

# %% [markdown]
# ## Concatenación
# ### + (signo más)

# %%
SELECT IDEmpleado, Nombre + ' ' + Apellido AS nombrecompleto
FROM Empleados;
# Out:
# (9 rows affected)
# IDEmpleado | nombrecompleto
# -----------+-----------------
# 1          | Nancy Davolio
# 2          | Andrew Fuller
# 3          | Janet Leverling
# 4          | Margaret Peacock
# 5          | Steven Buchanan
# 6          | Michael Suyama
# 7          | Robert King
# 8          | Laura Callahan
# 9          | Anne Dodsworth
# (9 rows)

# %% [markdown]
# ### || (doble pipe)

# %%
SELECT TOP(10) IDCliente, Pais, Region, Ciudad,
Pais || ',' || Region || ',' || Ciudad AS ubicacion
FROM Clientes;
# Out:
# (10 rows affected)
# IDCliente | Pais        | Region | Ciudad      | ubicacion
# ----------+-------------+--------+-------------+--------------------
# ALFKI     | Alemania    | NULL   | Berlin      | NULL
# ANATR     | Mexico      | NULL   | México D.F. | NULL
# ANTON     | Mexico      | NULL   | México D.F. | NULL
# AROUT     | Reino Unido | NULL   | London      | NULL
# BERGS     | Suecia      | NULL   | Luleå       | NULL
# BLAUS     | Alemania    | NULL   | Mannheim    | NULL
# BLONP     | Francia     | NULL   | Strasbourg  | NULL
# BOLID     | España      | NULL   | Madrid      | NULL
# BONAP     | Francia     | NULL   | Marseille   | NULL
# BOTTM     | Canadá      | BC     | Tsawassen   | Canadá,BC,Tsawassen
# (10 rows)
